# %%
# %pip install PySerial
# Out:
# ...
#      ---------------------------------------- 0.0/90.6 kB ? eta -:--:--
#      --------------------------- ------------ 61.4/90.6 kB 1.7 MB/s eta 0:00:01
#      ---------------------------------------- 90.6/90.6 kB 1.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import serial

# %%
ser = serial.Serial("COM9", 9600)
ser
# Out:
# Serial<id=0x1ddd82d3c10, open=True>(port='COM9', baudrate=9600, bytesize=8, parity='N', stopbits=1, timeout=None, xonxoff=False, rtscts=False, dsrdtr=False)

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x = np.array([int(ser.readline().decode().strip()) for _ in range(1000)])
plt.plot(x);

# %%
ser.close()
